# %% [markdown]
# # Assignment 1
# ## Megan Morgan
# ### July 6, 2022

# %%
from IPython.display import Image
Image("C:\\Users\\Megan\\OneDrive\\Documents\\Canine Companions\\2022 Jayla II\\Pictures\\Megan & Jayla2020.JPG")

# %% [markdown]
# ## My Programming Experience

# %%
print("I received my Bachelors in Computer Science in 2012, and have been working as \
a software developer or high school computer science teacher ever since.\n\
I have both educational and professional experience in Java, JavaScript, HTML5, \
C++, C, C#, and Cobol, in order of decreasing use. \
As well as numerous related processes, packages, and systems.\n\
Although I have never officially learned Python, \
I have dabbled a little with in online over the years.")
# Out:
# I received my Bachelors in Computer Science in 2012, and have been working as a software developer or high school computer science teacher ever since.
# I have both educational and professional experience in Java, JavaScript, HTML5, C++, C, C#, and Cobol, in order of decreasing use. As well as numerous related processes, packages, and systems.
# Although I have never officially learned Python, I have dabbled a little with in online over the years.

# %% [markdown]
# ## My GIS Experience

# %%
print("All of my GIS experience has been educational through the Master's program here at OU.")
# Out:
# All of my GIS experience has been educational through the Master's program here at OU.
