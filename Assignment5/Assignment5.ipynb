# %% [markdown]
# # Section 1
# After working through Chapter 13 of the Amos et al., 2021 textbook, use your newly developed knowledge to pip install two packages: numpy and matplotlib
#
# IMPORTANT: You may have to run the terminal/command prompt as Administrator. Also, try using "py" instead of "python" if using "python" (e.g. for python -m pip --version) does not work.
#
# First, list all installed packages. If numpy and matplotlib are already installed, continue with the screenshot part of this exercise (see below). For each package, install the package and then list all installed packages. Take a screenshot of the command prompt after the installation and the installed package list. Include the screenshots in this Jupyter notebook (revisit Exercise 1 to refresh your memory on how to include images in the notebook).

# %%
from IPython.display import Image
Image("C:\\Users\\Megan\\OneDrive\\Documents\\ArcGIS\\Projects\\GIS5653\\Assignment5\\install numpy.PNG")

# %%
Image("C:\\Users\\Megan\\OneDrive\\Documents\\ArcGIS\\Projects\\GIS5653\\Assignment5\\install matplotlib.PNG")
